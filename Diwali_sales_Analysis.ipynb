# %%
# !pip install seaborn
# Out:
# ...
#      ------------------------------------- 294.9/294.9 KB 19.0 MB/s eta 0:00:00
# ...
# WARNING: You are using pip version 22.0.4; however, version 24.1.2 is available.
# You should consider upgrading via the 'D:\python\python.exe -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# to install using pip in jupyter we use !p

# %%
df = pd.read_csv('Diwali Sales Data.csv',encoding='unicode_escape')
# this encoding is used to avoid errors
df.shape
# Out:
# (11251, 15)

# %%
df.head(10)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
# 5  1000588       Joni  P00057942      M     26-35   28               1
# 6  1001132       Balk  P00018042      F     18-25   25               1
# 7  1002092   Shivangi  P00273442      F       55+   61               0
# 8  1003224     Kushal  P00205642      M     26-35   35               0
# 9  1003650      Ginny  P00031142      F     26-35   26               1
#
#               State      Zone       Occupation Product_Category  Orders  \
# 0       Maharashtra   Western       Healthcare             Auto       1
# ...

# %%
df.info()
# this gives all the information about the columns that each column have how many rows and which type of data are present in it
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
df.drop(['Status','unnamed1'],axis=1, inplace=True)
# axis=1 means it will delete the entire column and inplace means it will save the process which is written in the statement
# inshort the inplace is used to save the current instance in the file , just as we edit any file and save it

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
pd.isnull(df)
# Out:
#        User_ID  Cust_name  Product_ID  Gender  Age Group    Age  \
# 0        False      False       False   False      False  False
# 1        False      False       False   False      False  False
# 2        False      False       False   False      False  False
# 3        False      False       False   False      False  False
# 4        False      False       False   False      False  False
# ...        ...        ...         ...     ...        ...    ...
# 11246    False      False       False   False      False  False
# 11247    False      False       False   False      False  False
# 11248    False      False       False   False      False  False
# 11249    False      False       False   False      False  False
# 11250    False      False       False   False      False  False
#
#        Marital_Status  State   Zone  Occupation  Product_Category  Orders  \
# 0               False  False  False       False             False   False
# ...

# %%
pd.isnull(df).sum()
# this will give us the sum of the null values in each column
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
df.dropna(inplace=True)
# this is to delete all the rows with null values in it

# %%
pd.isnull(df).sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
df['Amount'] = df['Amount'].astype('int')
# to change the datatype of the amount column to int

# %%
df['Amount'].dtype
# Out:
# dtype('int32')

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
df.rename(columns={'Cust_name':'Customer_name'},inplace=True)
# to rename the columns

# %%
df.describe()
# give max min mean like values for whole table
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610553
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355168
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
df[['Age','Orders','Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11251.000000  11251.000000  11239.000000
# mean      35.421207      2.489290   9453.610858
# std       12.754122      1.115047   5222.355869
# min       12.000000      1.000000    188.000000
# 25%       27.000000      1.500000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %% [markdown]
# ## Exploratory data analysis

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %%
sns.countplot(x="Gender" ,data=df , palette='Set2') 
# x axis is denoted by x which will show he gender and in data we have provided dataframs ie df
# Out:
# C:\Users\Ansh Mondal\AppData\Local\Temp\ipykernel_25400\3614316739.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Gender" ,data=df , palette='Set2')
# <Axes: xlabel='Gender', ylabel='count'>

# %%
# to add values to the columns 

ax = sns.countplot(x="Gender" ,data=df , palette='viridis') 

for bars in ax.containers:
    ax.bar_label(bars)

    # this is how we can add values of the columns
# Out:
# C:\Users\Ansh Mondal\AppData\Local\Temp\ipykernel_25400\1099722068.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x="Gender" ,data=df , palette='viridis')

# %%
df.groupby(['Gender'],as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

# the same groupby as sql here we are grouping the dataframe on the basis of genders and creating a column named amount which will provide the sum of amount grouped by gender and at last sorting them
# Out:
#   Gender       Amount
# 0      F  74335856.43
# 1      M  31913276.00

# %%
sales_gen = df.groupby(['Gender'],as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x='Gender' , y='Amount' , data=sales_gen , palette='Set2')
# Out:
# C:\Users\Ansh Mondal\AppData\Local\Temp\ipykernel_25400\1448875376.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Gender' , y='Amount' , data=sales_gen , palette='Set2')
# <Axes: xlabel='Gender', ylabel='Amount'>

# %% [markdown]
# * from the above graphs we can see that most of the buyers are female and also the purchases are more in the case of females than males.

# %% [markdown]
# ### Age

# %%
sns.countplot(data=df , x = "Age Group" , hue='Gender')
# this hue is used to classify the population on the basis of Gender as specified
# Out:
# <Axes: xlabel='Age Group', ylabel='count'>

# %%
ax2 = sns.countplot(data=df , x = "Age Group" , hue='Gender' , palette='Set2')

for bars in ax2.containers:
    ax2.bar_label(bars)

# this shows the count of the people on the basis of age and gender who went shopping

# %%
sales_age = df.groupby(['Age Group'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x='Age Group', y='Amount', data=sales_age , palette='viridis')

# and this plot shows the amount spent by the various age groups
# Out:
# C:\Users\Ansh Mondal\AppData\Local\Temp\ipykernel_25400\2360673833.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Age Group', y='Amount', data=sales_age , palette='viridis')
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %% [markdown]
# * the above graphs we can see that most of the buyers are in the age of 26-35 and are women

# %% [markdown]
# ### State

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %%
sales_state = df.groupby(['State'],as_index=False)['Orders'].sum().sort_values(by='Orders',ascending=False).head(10)

# this will show the top 10 states which have the most orders

sns.barplot(data=sales_state , x='State' , y='Orders' , palette='Set2')
sns.set(rc={'figure.figsize':(17,5)}) # this is to set the size of the chart
# Out:
# C:\Users\Ansh Mondal\AppData\Local\Temp\ipykernel_25400\2948283100.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=sales_state , x='State' , y='Orders' , palette='Set2')

# %%
sales_state_amt = df.groupby(['State'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(10)

sns.barplot(data=sales_state_amt , x='State' , y='Amount' , palette='viridis')
sns.set(rc={'figure.figsize':(17,5)})
# Out:
# C:\Users\Ansh Mondal\AppData\Local\Temp\ipykernel_25400\3768959863.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=sales_state_amt , x='State' , y='Amount' , palette='viridis')

# %% [markdown]
# * from the above graphs we can see that the state which have most sales is the uttar pradesh and also this state has spent the most amount , also we have the top 10 states listed in the graphs

# %% [markdown]
# ### Marital Status

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %%
ax3 = sns.countplot(data=df , x='Marital_Status' , palette="Set2")

for bars in ax3.containers:
    ax3.bar_label(bars)
    
sns.set(rc={'figure.figsize':(7,5)})
# Out:
# C:\Users\Ansh Mondal\AppData\Local\Temp\ipykernel_25400\3895731370.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax3 = sns.countplot(data=df , x='Marital_Status' , palette="Set2")

# %%
sales_marital = df.groupby(['Marital_Status','Gender'],as_index=False)['Amount'].sum().sort_values(by='Amount' , ascending=False)

sns.set(rc={'figure.figsize':(7,5)})

sns.barplot(data = sales_marital , x='Marital_Status' , y='Amount' , hue='Gender' , palette='Set2')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %% [markdown]
# * Here we can say by the above graphs that the married women are the most to buy and spend more amount than unmarried

# %% [markdown]
# ### Occupation

# %%
sns.set(rc={'figure.figsize':(20,5)})

ax4 = sns.countplot(data=df , x='Occupation' , palette='viridis')

for bars in ax4.containers:
    ax4.bar_label(bars)
# Out:
# C:\Users\Ansh Mondal\AppData\Local\Temp\ipykernel_25400\597891152.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax4 = sns.countplot(data=df , x='Occupation' , palette='viridis')

# %%
sales_occu = df.groupby(['Occupation'],as_index=False)['Amount'].sum().sort_values(by='Amount' , ascending=False)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data=sales_occu , x='Occupation' , y='Amount' , palette='Set2')
# Out:
# C:\Users\Ansh Mondal\AppData\Local\Temp\ipykernel_25400\522630358.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=sales_occu , x='Occupation' , y='Amount' , palette='Set2')
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# * this graph concludes that the most amount spent by any sector is IT sector

# %%
ax5 = sns.countplot(data=df , x='Product_Category',palette="viridis")

sns.set(rc={'figure.figsize':(25,5)})

for bars in ax5.containers:
    ax5.bar_label(bars)
# Out:
# C:\Users\Ansh Mondal\AppData\Local\Temp\ipykernel_25400\2602553916.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax5 = sns.countplot(data=df , x='Product_Category',palette="viridis")

# %%
sales_Product = df.groupby(['Product_Category'],as_index=False)['Amount'].sum().sort_values(by='Amount' , ascending=False).head(10)

sns.barplot(data=sales_Product , x='Product_Category' , y='Amount' , palette='viridis')

sns.set(rc={'figure.figsize':(25,5)})
# Out:
# C:\Users\Ansh Mondal\AppData\Local\Temp\ipykernel_25400\3479165902.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=sales_Product , x='Product_Category' , y='Amount' , palette='viridis')

# %% [markdown]
# * from the above two graphs we came to know that the most selling product was of category clothing but the most amount spent on the category is food

# %%
sales_PID = df.groupby(['Product_ID'],as_index=False)['Orders'].sum().sort_values(by='Orders' , ascending=False).head(10)

sns.barplot(data=sales_PID , x='Product_ID' , y='Orders' , palette='magma')
sns.set(rc={'figure.figsize':(15,5)})
# Out:
# C:\Users\Ansh Mondal\AppData\Local\Temp\ipykernel_25400\1388536212.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=sales_PID , x='Product_ID' , y='Orders' , palette='magma')

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ### From the above data analysis we came to know that the married womens of age 26-35 working in IT, Healthcare section are more likely to buy products from food , clothing and electronics category
